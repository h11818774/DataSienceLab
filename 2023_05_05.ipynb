# %% [markdown]
# # ZEB Projekt
# ## Stand 2023_05_05

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
df = pd.read_excel('data/dataset_2023.xlsx')
df = df.drop('Unnamed: 0', axis=1)

# %%
def replaceComma(text):
    if "." in str(text): 
        return str("".join(str(text).split("."))).replace(",",".")
    else:
        return str(text).replace(",",".")

def removeLetters(text):
    return "".join(c for c in text if c.isdigit() or c == ".")

def removeThousandPoint(text):
    return str(text).replace(".","")

from datetime import datetime
from dateutil.relativedelta import relativedelta

def calculate_age(registration_date):
    if registration_date == "Neuwagen":
        return 0
    else:
        today = datetime.now()
        date = datetime.strptime(registration_date, "%m/%Y")
        delta = relativedelta(today, date)
        return (delta.years * 12) + delta.months
    
def getConsumption(consumption):
    return str(consumption).split()[0]

# %%
columnsNumeric = ["milage", "duration", "monthly_fee", "horsepower", "emission_value", "kilowatts", "consumption"]
def preProcess(columnsNumeric, df):
    
    # calculating age
    
    df['first_registration'] = df['first_registration'].apply(calculate_age)
    
    
    # removing unnecesary characters from consumption
    
    df['consumption'] = df['consumption'].apply(getConsumption)
    
    
    for i in range(len(columnsNumeric)):
        
        
        df[columnsNumeric[i]] = df[columnsNumeric[i]].apply(replaceComma)
        df[columnsNumeric[i]] = df[columnsNumeric[i]].apply(removeLetters)
    
    # removing thousand point from milage column
    
    df["milage"] = df["milage"].apply(removeThousandPoint)
    
    
    # replacing "" and "nan" values from the different 

    df = df.replace('', np.nan)
    df = df.replace('nan', np.nan)
    
    

    
    df[df.columns.difference(['brand_name', 'model_name','fuel_type', 'gear' ])] = df[df.columns.difference(['brand_name', 'model_name','fuel_type', 'gear' ])].astype(float)


    return df

# %%
def preprocessor(df):
    columnsNumeric = ["milage", "duration", "monthly_fee", "horsepower", "emission_value", "kilowatts", "consumption"]
    
    df = preProcess(columnsNumeric, df)
    
    return df

# %%
preprocess = FunctionTransformer(preprocessor)

# %%
# Define categorical features
categorical_features = ['brand_name', 'model_name', 'gear', 'fuel_type']
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
# Combine preprocessing steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', preprocess, columnsNumeric),
        ('cat', categorical_transformer, categorical_features)])

# %%
# Define model
model = DecisionTreeRegressor()

# %%
# X = df.drop('monthly_fee', axis=1) # assume we want to predict 'monthly_fee'
# y = pd.DataFrame(df['monthly_fee'])
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

def split(df):
    X = df.drop('monthly_fee', axis=1) # assume we want to predict 'monthly_fee'
    y = pd.DataFrame(df['monthly_fee'])
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    return(X_train, X_test, y_train, y_test)

# %%
# Combine preprocessing and model training steps into a pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

# %%
pipeline.fit(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'first_registration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/3b/48y4zyts7j33x2t7t7dq18w40000gn/T/ipykernel_9441/2437470115.py in <module>
# ----> 1 pipeline.fit(df)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py in fit(self, X, y)
#     468         # we use fit_transform to make sure to set sparse_output_ (for which we
#     469         # need the transformed data) to have consistent output type in predict
# --> 470         self.fit_transform(X, y=y)
#     471         return self
#     472
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py in fit_transform(self, X, y)
#     505         self._validate_remainder(X)
#     506
# --> 507         result = self._fit_transform(X, y, _fit_transform_one)
#     508
#     509         if not result:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py in _fit_transform(self, X, y, func, fitted)
#     432             self._iter(fitted=fitted, replace_strings=True))
#     433         try:
# --> 434             return Parallel(n_jobs=self.n_jobs)(
#     435                 delayed(func)(
#     436                     transformer=clone(trans) if not fitted else trans,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
#    1044                 self._iterating = self._original_iterator is not None
#    1045
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     752     with _print_elapsed_time(message_clsname, message):
#     753         if hasattr(transformer, 'fit_transform'):
# --> 754             res = transformer.fit_transform(X, y, **fit_params)
#     755         else:
#     756             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_function_transformer.py in transform(self, X)
#     145             Transformed input.
#     146         """
# --> 147         return self._transform(X, func=self.func, kw_args=self.kw_args)
#     148
#     149     def inverse_transform(self, X):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_function_transformer.py in _transform(self, X, func, kw_args)
#     169             func = _identity
#     170
# --> 171         return func(X, **(kw_args if kw_args else {}))
#     172
#     173     def _more_tags(self):
#
# /var/folders/3b/48y4zyts7j33x2t7t7dq18w40000gn/T/ipykernel_9441/798407738.py in preprocessor(df)
#       2     columnsNumeric = ["milage", "duration", "monthly_fee", "horsepower", "emission_value", "kilowatts", "consumption"]
#       3
# ----> 4     df = preProcess(columnsNumeric, df)
#       5
#       6     return df
#
# /var/folders/3b/48y4zyts7j33x2t7t7dq18w40000gn/T/ipykernel_9441/1172772074.py in preProcess(columnsNumeric, df)
#       4     # calculating age
#       5
# ----> 6     df['first_registration'] = df['first_registration'].apply(calculate_age)
#       7
#       8
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'first_registration'

# %%
X_train
# Out:
#        brand_name                                      model_name      milage  \
# 13460        Audi                    A1 Sportback 25 TFSI intense    3.000 km
# 15717        Seat                        Ibiza FR Austria 1.0 TSI   24.000 km
# 5620          BMW                     X3 M Competition Individual   13.000 km
# 6901          BMW  520 d Touring G31*M-Paket*Leder*HeadUP*19Zoll*  101.100 km
# 12505        Seat                 Leon SP Kombi Reference 1.0 TSI    5.000 km
# ...           ...                                             ...         ...
# 9225   Volkswagen      Touran VW Comfortline TDI SCR DSG 5-Sitzer   85.600 km
# 13123  Volkswagen                             T-Cross VW Life TSI       10 km
# 9845         Opel      Insignia ST 1.6 CDTI Aut. LED,Navi,AGR,SHZ   44.043 km
# 10799  Volkswagen                        Golf VW Variant Life TDI    5.000 km
# 2732         Seat                      Tarraco FR eHYBRID 245 DSG   15.000 km
#
#       first_registration              duration                gear  \
# 13460            11/2022  48 Monat (anpassbar)  Manuelle Schaltung
# 15717            03/2022  48 Monat (anpassbar)  Manuelle Schaltung
# 5620             08/2021  36 Monat (anpassbar)           Automatik
# 6901             03/2019  48 Monat (anpassbar)           Automatik
# 12505            01/2023  48 Monat (anpassbar)  Manuelle Schaltung
# ...                  ...                   ...                 ...
# 9225             11/2018  48 Monat (anpassbar)           Automatik
# 13123            05/2022  48 Monat (anpassbar)  Manuelle Schaltung
# 9845             04/2020  48 Monat (anpassbar)           Automatik
# 10799            01/2023  48 Monat (anpassbar)  Manuelle Schaltung
# 2732             11/2022  48 Monat (anpassbar)           Automatik
#
#       emission_value    consumption horsepower kilowatts fuel_type
# 13460       114 g/km   5,0 l/100 km      95 PS     70 kW    Benzin
# 15717       131 g/km   6,0 l/100 km      95 PS     70 kW    Benzin
# 5620        130 g/km   5,0 l/100 km     510 PS    375 kW    Benzin
# 6901        189 g/km   7,0 l/100 km     190 PS    140 kW    Benzin
# 12505       230 g/km  10,0 l/100 km      90 PS     66 kW    Benzin
# ...              ...            ...        ...       ...       ...
# 9225        129 g/km   5,0 l/100 km     116 PS     85 kW    Diesel
# 13123            NaN            NaN      95 PS     70 kW    Benzin
# 9845        138 g/km   6,0 l/100 km     136 PS    100 kW    Diesel
# 10799        42 g/km   2,0 l/100 km     116 PS     85 kW    Diesel
# 2732        177 g/km   6,0 l/100 km     150 PS    110 kW    Hybrid
#
# [15246 rows x 11 columns]

# %%
print("Model score: %.3f" % pipeline.score(X_test, y_test))
